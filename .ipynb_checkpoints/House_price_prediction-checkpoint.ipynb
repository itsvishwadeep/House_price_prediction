# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
hp = pd.read_csv('House_Price_India.csv')
hp.head()
hp.drop(['Renovation Year'],axis=1)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
hp.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
hp['number of bedrooms'].value_counts()
# Out:
# number of bedrooms
# 3     6612
# 4     4724
# 2     1844
# 5     1079
# 6      176
# 1      136
# 7       30
# 8       11
# 9        3
# 10       3
# 33       1
# 11       1
# Name: count, dtype: int64

# %%
hp['number of bathrooms'].value_counts()
# Out:
# number of bathrooms
# 2.50    3678
# 1.00    2509
# 1.75    2062
# 2.25    1378
# 2.00    1323
# 1.50     968
# 2.75     831
# 3.00     510
# 3.50     504
# 3.25     424
# 3.75     101
# 4.00      81
# 4.50      72
# 4.25      56
# 0.75      47
# 4.75      17
# 5.00      15
# 5.25      12
# 5.50       8
# 1.25       7
# 0.50       3
# 6.00       3
# 8.00       2
# 5.75       2
# 6.25       2
# 6.75       2
# 6.50       1
# 7.50       1
# 7.75       1
# Name: count, dtype: int64

# %%
hp.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
X =hp[['number of bedrooms', 'number of bathrooms',
       'number of floors',
       'condition of the house',
       'Built Year','Number of schools nearby']]
Y = hp['Price']

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
bedroom_encoder = LabelEncoder()
bathroom_encoder = LabelEncoder()
condition_encoder = LabelEncoder()
floors_encoder = LabelEncoder()
schools_encoder = LabelEncoder()

# %%
import warnings
warnings.filterwarnings('ignore')
bedroom_encoder.fit(pd.DataFrame(X['number of bedrooms']))
X['number of bedrooms'] = bedroom_encoder.transform(X['number of bedrooms'])

bathroom_encoder.fit(pd.DataFrame(X['number of bathrooms']))
X['number of bathrooms'] = bathroom_encoder.transform(X['number of bathrooms'])

condition_encoder.fit(pd.DataFrame(X['condition of the house']))
X['condition of the house'] = condition_encoder.transform(X['condition of the house'])

floors_encoder.fit(pd.DataFrame(X['number of floors']))
X['number of floors'] = floors_encoder.transform(X['number of floors'])

schools_encoder.fit(pd.DataFrame(X['Number of schools nearby']))
X['Number of schools nearby'] = schools_encoder.transform(X['Number of schools nearby'])

# %%
X.head()
# Out:
#    number of bedrooms  number of bathrooms  number of floors  \
# 0                   4                    8                 2
# 1                   3                    8                 1
# 2                   4                    9                 1
# 3                   3                    8                 2
# 4                   2                    6                 1
#
#    condition of the house  Built Year  Number of schools nearby
# 0                       4        1921                         1
# 1                       4        1909                         1
# 2                       2        1939                         0
# 3                       2        2001                         2
# 4                       3        1929                         0

# %%
X['number of bedrooms'].value_counts()
# Out:
# number of bedrooms
# 2     6612
# 3     4724
# 1     1844
# 4     1079
# 5      176
# 0      136
# 6       30
# 7       11
# 8        3
# 9        3
# 11       1
# 10       1
# Name: count, dtype: int64

# %%
X['number of bathrooms'].value_counts()
# Out:
# number of bathrooms
# 8     3678
# 2     2509
# 5     2062
# 7     1378
# 6     1323
# 4      968
# 9      831
# 10     510
# 12     504
# 11     424
# 13     101
# 14      81
# 16      72
# 15      56
# 1       47
# 17      17
# 18      15
# 19      12
# 20       8
# 3        7
# 0        3
# 22       3
# 28       2
# 21       2
# 23       2
# 25       2
# 24       1
# 26       1
# 27       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(X.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((11696, 6), (2924, 6), (11696,), (2924,))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = model.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
score = r2_score(Y_test,Y_predict)
mae = mean_absolute_error(Y_test,Y_predict)
mse = mean_squared_error(Y_test,Y_predict)
print("R2 score is ", score)
print(" Mean absolute error is ",mae)
print( " Mean squared erroe is ",mse)
# Out:
# R2 score is  0.36576407924137255
#  Mean absolute error is  190147.67376064562
#  Mean squared erroe is  89375860215.33357

# %%
import joblib

# %%
joblib.dump(model,'House_pred_india.pkl')
# Out:
# ['House_pred_india.pkl']

# %%
from flask import Flask
from flask import render_template
import joblib
from flask import request

# %%
app = Flask(__name__)
model = joblib.load('House_pred_india.pkl')
@app.route('/')
def hello(name=None):
    return render_template('index.html',name = name)

@app.route('/result',methods=['GET','POST'])
def get_value():
    if request.method=="POST":
        bedrooms=int(request.form.get('number of bedrooms'))
        bathrooms=int(request.form.get('number of bathrooms'))
        floors=int(request.form.get('number of floors'))
        condition=int(request.form.get('condition of the house'))
        schools=int(request.form.get('Number of schools nearby'))
        predict=model.predict([[bedrooms,bathrooms,floors,condition,schools]])
        print(predict[0])

# %%
if __name__=="__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [15/Jul/2024 21:15:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jul/2024 21:15:27] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Jul/2024 21:15:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jul/2024 21:15:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jul/2024 21:16:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jul/2024 21:18:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jul/2024 21:18:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jul/2024 21:19:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jul/2024 21:19:39] "GET / HTTP/1.1" 200 -
